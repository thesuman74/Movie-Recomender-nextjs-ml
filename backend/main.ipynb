# %%
import pandas as pd

# %%
movies=pd.read_csv('dataset.csv')

# %%
movies.head()
# Out:
#       id                        title                 genre original_language  \
# 0    278     The Shawshank Redemption           Drama,Crime                en
# 1  19404  Dilwale Dulhania Le Jayenge  Comedy,Drama,Romance                hi
# 2    238                The Godfather           Drama,Crime                en
# 3    424             Schindler's List     Drama,History,War                en
# 4    240       The Godfather: Part II           Drama,Crime                en
#
#                                             overview  popularity release_date  \
# 0  Framed in the 1940s for the double murder of h...      94.075   1994-09-23
# 1  Raj is a rich, carefree, happy-go-lucky second...      25.408   1995-10-19
# 2  Spanning the years 1945 to 1955, a chronicle o...      90.585   1972-03-14
# 3  The true story of how businessman Oskar Schind...      44.761   1993-12-15
# 4  In the continuing saga of the Corleone crime f...      57.749   1974-12-20
#
#    vote_average  vote_count
# ...

# %%
movies.isnull().sum()
# Out:
# id                    0
# title                 0
# genre                 3
# original_language     0
# overview             13
# popularity            0
# release_date          0
# vote_average          0
# vote_count            0
# dtype: int64

# %% [markdown]
# Selecting Features For The System

# %%
movies.columns
# Out:
# Index(['id', 'title', 'genre', 'original_language', 'overview', 'popularity',
#        'release_date', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
movies = movies [['id','title','genre','overview']]

# %%
movies.head()
# Out:
#       id                        title                 genre  \
# 0    278     The Shawshank Redemption           Drama,Crime
# 1  19404  Dilwale Dulhania Le Jayenge  Comedy,Drama,Romance
# 2    238                The Godfather           Drama,Crime
# 3    424             Schindler's List     Drama,History,War
# 4    240       The Godfather: Part II           Drama,Crime
#
#                                             overview
# 0  Framed in the 1940s for the double murder of h...
# 1  Raj is a rich, carefree, happy-go-lucky second...
# 2  Spanning the years 1945 to 1955, a chronicle o...
# 3  The true story of how businessman Oskar Schind...
# 4  In the continuing saga of the Corleone crime f...

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                  genre  \
# 0                                          Drama,Crime
# 1                                 Comedy,Drama,Romance
# 2                                          Drama,Crime
# ...

# %%
movies.loc [:,'tags'] = movies['genre']+movies['overview']

# %%
movies
# Out:
#             id                                          title  \
# 0        278.0                       The Shawshank Redemption
# 1      19404.0                    Dilwale Dulhania Le Jayenge
# 2        238.0                                  The Godfather
# 3        424.0                               Schindler's List
# 4        240.0                         The Godfather: Part II
# ...        ...                                            ...
# 9996  331446.0                       Sharknado 3: Oh Hell No!
# 9997   13995.0                                Captain America
# 9998    2312.0  In the Name of the King: A Dungeon Siege Tale
# 9999  455957.0                                         Domino
# tags       NaN                                            NaN
#
#                                                  genre  \
# 0                                          Drama,Crime
# 1                                 Comedy,Drama,Romance
# ...

# %%
movies = movies.drop(columns=['genre','overview'])

# %%
movies
# Out:
#             id                                          title  \
# 0        278.0                       The Shawshank Redemption
# 1      19404.0                    Dilwale Dulhania Le Jayenge
# 2        238.0                                  The Godfather
# 3        424.0                               Schindler's List
# 4        240.0                         The Godfather: Part II
# ...        ...                                            ...
# 9996  331446.0                       Sharknado 3: Oh Hell No!
# 9997   13995.0                                Captain America
# 9998    2312.0  In the Name of the King: A Dungeon Siege Tale
# 9999  455957.0                                         Domino
# tags       NaN                                            NaN
#
#                                                    tags
# 0     Drama,CrimeFramed in the 1940s for the double ...
# 1     Comedy,Drama,RomanceRaj is a rich, carefree, h...
# ...

# %%
movies
# Out:
#             id                                          title  \
# 0        278.0                       The Shawshank Redemption
# 1      19404.0                    Dilwale Dulhania Le Jayenge
# 2        238.0                                  The Godfather
# 3        424.0                               Schindler's List
# 4        240.0                         The Godfather: Part II
# ...        ...                                            ...
# 9996  331446.0                       Sharknado 3: Oh Hell No!
# 9997   13995.0                                Captain America
# 9998    2312.0  In the Name of the King: A Dungeon Siege Tale
# 9999  455957.0                                         Domino
# tags       NaN                                            NaN
#
#                                                    tags
# 0     Drama,CrimeFramed in the 1940s for the double ...
# 1     Comedy,Drama,RomanceRaj is a rich, carefree, h...
# ...

# %%
movies = movies.drop(index='tags')

# %%
movies
# Out:
#             id                                          title  \
# 0        278.0                       The Shawshank Redemption
# 1      19404.0                    Dilwale Dulhania Le Jayenge
# 2        238.0                                  The Godfather
# 3        424.0                               Schindler's List
# 4        240.0                         The Godfather: Part II
# ...        ...                                            ...
# 9995   10196.0                             The Last Airbender
# 9996  331446.0                       Sharknado 3: Oh Hell No!
# 9997   13995.0                                Captain America
# 9998    2312.0  In the Name of the King: A Dungeon Siege Tale
# 9999  455957.0                                         Domino
#
#                                                    tags
# 0     Drama,CrimeFramed in the 1940s for the double ...
# 1     Comedy,Drama,RomanceRaj is a rich, carefree, h...
# ...

# %% [markdown]
# Converting text of tags columns in vectorm form
# There are two different ways they are:
# 1. Bag of words and
# 2. TF-IDF

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv= CountVectorizer(max_features=10000, stop_words='english')

# %%
cv
# Out:
# CountVectorizer(max_features=10000, stop_words='english')

# %%
vector= cv.fit_transform(movies['tags'].values.astype('U')).toarray()

# %%
vector.shape
# Out:
# (10000, 10000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.06253054, 0.05802589, ..., 0.07963978, 0.07597372,
#         0.03798686],
#        [0.06253054, 1.        , 0.08980265, ..., 0.        , 0.        ,
#         0.        ],
#        [0.05802589, 0.08980265, 1.        , ..., 0.02541643, 0.03636965,
#         0.        ],
#        ...,
#        [0.07963978, 0.        , 0.02541643, ..., 1.        , 0.03327792,
#         0.03327792],
#        [0.07597372, 0.        , 0.03636965, ..., 0.03327792, 1.        ,
#         0.04761905],
#        [0.03798686, 0.        , 0.        , ..., 0.03327792, 0.04761905,
#         1.        ]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Assuming 'cosine_similarity_matrix' is your cosine similarity result
cosine_similarity_matrix = np.array([
    [1.0, 0.06253054, 0.05802589, ..., 0.07963978, 0.07597372, 0.03798686],
    [0.06253054, 1.0, 0.08980265, ..., 0.0, 0.0, 0.0],
    [0.05802589, 0.08980265, 1.0, ..., 0.02541643, 0.03636965, 0.0],
    ...,
    [0.07963978, 0.0, 0.02541643, ..., 1.0, 0.03327792, 0.03327792],
    [0.07597372, 0.0, 0.03636965, ..., 0.03327792, 1.0, 0.04761905],
    [0.03798686, 0.0, 0.0, ..., 0.03327792, 0.04761905, 1.0]
])

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Create the heatmap
sns.heatmap(cosine_similarity_matrix, cmap="coolwarm", annot=False, fmt=".2f")

# Add labels and title
plt.title("Cosine Similarity Heatmap")
plt.xlabel("Items")
plt.ylabel("Items")

# Display the heatmap
plt.show()

# %%
movies[movies['title']== "The Godfather"]
# Out:
#       id          title                                               tags
# 2  238.0  The Godfather  Drama,CrimeSpanning the years 1945 to 1955, a ...

# %%
movies[movies['title']== "The Godfather"].index[0]
# Out:
# 2

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10000 non-null  float64
#  1   title   10000 non-null  object
#  2   tags    9985 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 312.5+ KB

# %%
movies['id'] = movies['id'].astype(int)

# %%
movies[movies['title']== "The Godfather"]
# Out:
#     id          title                                               tags
# 2  238  The Godfather  Drama,CrimeSpanning the years 1945 to 1955, a ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10000 non-null  int32
#  1   title   10000 non-null  object
#  2   tags    9985 non-null   object
# dtypes: int32(1), object(2)
# memory usage: 273.4+ KB

# %%
movies['id'] = movies['id'].astype('int64')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10000 non-null  int64
#  1   title   10000 non-null  object
#  2   tags    9985 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 312.5+ KB

# %%
distance=sorted(list(enumerate(similarity[2])), reverse=True, key= lambda vector:vector[1])
for i in distance[0:5]:
    print (movies.iloc[i[0]].title)
# Out:
# The Godfather
# The Godfather: Part II
# Felon
# House of Gucci
# Gotti

# %%
def recommand(movies_name):
    index= movies[movies['title']==movies_name].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector: vector[1])
    for i in distance[0:5]:
            print (movies.iloc[i[0]].title)

# %%
recommand("Iron Man")
# Out:
# Iron Man
# Mazinger Z: Infinity
# Justice League Dark
# Iron Man 3
# The Colony

# %%
import pickle

# %%
pickle.dump(movies, open('movies_list.pkl', 'wb'))

# %%
pickle.dump(similarity, open('similarity.pkl', 'wb'))

# %%
pickle.load(open('movies_list.pkl','rb'))
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Drama,CrimeFramed in the 1940s for the double ...
# 1     Comedy,Drama,RomanceRaj is a rich, carefree, h...
# 2     Drama,CrimeSpanning the years 1945 to 1955, a ...
# ...
